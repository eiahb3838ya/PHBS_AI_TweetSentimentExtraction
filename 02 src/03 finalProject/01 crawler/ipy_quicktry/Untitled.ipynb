# %%
import requests
from bs4 import BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-10ca0c9990f3> in <module>
# ----> 1 import requests
#       2 from bs4 import BeautifulSoup
#
# ModuleNotFoundError: No module named 'requests'

# %%
res = requests.get("https://www.55188.com/forum.php?mod=forumdisplay&fid=8&filter=typeid&typeid=7")
# res=requests.get(req_link)
res.encoding=('gbk')
html_doc=res.text
soup = BeautifulSoup(html_doc, 'html.parser')
# Out:
# [<article class="a-excerpt" id="normalthread_8966355">
#  <header class="head cl">
#  <figure class="z">
#  <a class="avatar-out" href="https://www.55188.com/space-uid-2245452.html" target="_blank">
#  <img class="lazy" data-original="http://img.55188.com/default/avatar.png" src="/uc_server/images/noavatar_middle.gif?gJe"/>
#  </a>
#  </figure>
#  <div class="article-box">
#  <a class="author-name" href="https://www.55188.com/space-uid-2245452.html" target="_blank">绸缎</a>
#  <em class="icon-level icon-level-c2">Lv.4</em>
#  <span class="icon-group"></span>
#  <div class="y article-action">
#  <a href="javascript:;"></a>
#  <ul>
#  <li class="" id="lx_focus_thread">
#  <a href="javascript:;" onclick="lxtid_focus('thread', 8966355)">关注</a>
#  </li>
#  <li><a href="https://www.55188.com/home.php?mod=spacecp&amp;ac=favorite&amp;type=thread&amp;id=8966355&amp;formhash=1978340c" id="k_favorite8966355" onclick="showWindow(this.id, this.href, 'get', 0);">收藏</a></li>
#  </ul>
#  </div>
# ...

# %%
soup.findAll('div',class_ = "body cl")
# Out:
# <div class="body cl">
# <div class="note">
# <div class="article-title cl">
# <a class="subject" href="https://www.55188.com/forum.php?mod=viewthread&amp;tid=8966355&amp;extra=page%3D1%26filter%3Dtypeid%26typeid%3D7" onclick="atarget(this)">中国工商银行爆雷！下周银行股全线跌停！</a>
# <em><a href="https://www.55188.com/forum.php?mod=forumdisplay&amp;fid=8&amp;filter=typeid&amp;typeid=7" target="_blank">[新闻]</a></em>
# <span class="type-bright"><img alt="3个点亮" src="template/static/sns/image/forum/iconligth.png" title="3个点亮"/></span>
# <span class="bright">3</span>
# </div>
# <div class="nei cl">
# <a href="https://www.55188.com/thread-8966355-1-1.html" target="_blank">上海工商银行分行行长主动招
#
# 供约32个女下属被潜规则！</a>
# </div>
# </div>
# </div>
